# %%
from selenium import webdriver # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs # 데이터 분석을 용이하게 정제
import pandas as pd

# %%
driver = webdriver.Chrome('chromedriver.exe')
url = "https://www.genie.co.kr/chart/top200"
driver.get(url)

txt = driver.page_source
html = bs(txt)
# print(html)
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_3880\397416716.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[6], line 3
#       1 driver = webdriver.Chrome('chromedriver.exe')
#       2 url = "https://www.genie.co.kr/chart/top200"
# ----> 3 driver.get(url)
#       5 txt = driver.page_source
#       6 html = bs(txt)
#
# File c:\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File c:\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File c:\Python311\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=110.0.5481.178)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x011537D3]
# 	(No symbol) [0x010E8B81]
# 	(No symbol) [0x00FEB36D]
# 	(No symbol) [0x00FCE5DA]
# 	(No symbol) [0x0103F0CB]
# 	(No symbol) [0x01050A56]
# 	(No symbol) [0x0103B216]
# 	(No symbol) [0x01010D97]
# 	(No symbol) [0x0101253D]
# 	GetHandleVerifier [0x013CABF2+2510930]
# 	GetHandleVerifier [0x013F8EC1+2700065]
# 	GetHandleVerifier [0x013FC86C+2714828]
# 	GetHandleVerifier [0x01203480+645344]
# 	(No symbol) [0x010F0FD2]
# 	(No symbol) [0x010F6C68]
# 	(No symbol) [0x010F6D4B]
# 	(No symbol) [0x01100D6B]
# 	BaseThreadInitThunk [0x750300F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77187BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77187B8E+238]

# %%
# 소스를 확인 하였더니 노래 한곡이 하나의 tr로 묶여 있음을 확인 할 수 있다.
len(html.select('tbody > tr'))
songs = html.select('tbody > tr')
song = songs[0] #한 곡의 정보 (1등)

# %%
from pprint import pprint
pprint(song)
# Out:
# <tr class="list" songid="99570005">
# <td class="check"><input class="select-check" title="Ditto" type="checkbox"/></td>
# <td class="number">1
#
#                                     <span class="rank">
# <span class="rank"><span class="rank-none"><span class="hide">유지</span></span></span>
# </span>
# </td>
# <td><a class="cover" href="#" onclick="fnViewAlbumLayer('83325577');return false;"><span class="mask"></span><img alt="NewJeans 'OMG'" onerror="this.src='//image.genie.co.kr/imageg/web/common/blank_68.gif';" src="//image.genie.co.kr/Y/IMAGE/IMG_ALBUM/083/325/577/83325577_1672649874616_1_140x140.JPG/dims/resize/Q_80,0"/></a></td>
# <td class="link"><a class="btn-basic btn-info" href="#" onclick="fnViewSongInfo('99570005');return false;">곡 제목 정보 페이지</a></td>
# <td class="info">
# <a class="title ellipsis" href="#" onclick="fnPlaySong('99570005','1');return false;" title="재생">
#
#
#
#
#
#
#
#                                                 Ditto</a>
# <a class="artist ellipsis" href="#" onclick="fnViewArtist('81490206');return false;">NewJeans</a>
# <div class="toggle-button-box">
# <button class="btn artist-etc" onclick="fnRelationArtistList('99570005');" type="button">외</button>
# <ul class="list" id="RelationArtist_99570005"></ul>
# </div>
# <i class="bar">|</i>
# <a class="albumtitle ellipsis" href="#" onclick="fnViewAlbumLayer('83325577');return false;">NewJeans 'OMG'</a>
# </td>
# <td class="btns"><a class="btn-basic btn-listen" href="#" onclick="fnPlaySong('99570005;' ,'1'); return false;" title="재생">듣기</a></td>
# <td class="btns"><a class="btn-basic btn-add" href="#" onclick="fnPlaySong('99570005;' ,'3'); return false;" title="추가">재생목록에 추가</a></td>
# <td class="btns"><button class="btn-basic btn-album" id="add_my_album_99570005" onclick="fnAddMyAlbumForm('#add_my_album_99570005' , '99570005' ,10, 10);return false;" songid="99570005" type="button">플레이리스트에 담기</button></td>
# <td class="btns"><a class="btn-basic btn-down" href="#" onclick="fnDownSong('99570005');return false;" title="다운">다운로드</a></td>
# <td class="btns">
# <div class="toggle-button-box lyr-mv" id="list-mv_99570005">
# <a alt="Ditto" class="btn btn-basic btn-mv" href="#" onclick="fnPlayMv('99570005','3'); return false;" title="뮤비">뮤직비디오 보기</a>
# </div>
# </td>
# <td class="more">
# <div class="toggle-button-box">
# <button class="btn btn-basic btn-more" type="button">더보기</button>
# <ul class="list">
# <li><a class="item" href="#" onclick="shareDo('99570005');return false;" title="공유">공유하기/음악나누기</a></li>
# <li><a class="item" href="#" onclick="fnGiftSong('99570005');return false;" title="선물">선물하기</a></li>
# </ul>
# </div>
# </td>
# </tr>

# %%
title = song.select('a.title')[0].text.strip()
title
# Out:
# 'Ditto'

# %%
artist = song.select('a.artist')[0].text.strip()
artist
# Out:
# 'NewJeans'

# %%
from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://www.genie.co.kr/chart/top200'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

songs = html.select('tbody > tr')

song_data = []
rank = 1

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()

    song_data.append(['Genie',rank,title,singer])
    rank += 1


url = 'https://www.genie.co.kr/chart/top200?ditc=D&ymd=20230228&hh=14&rtm=Y&pg=2'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

songs = html.select('tbody > tr')

for song in songs:
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text.strip()

    song_data.append(['Genie',rank,title,singer])
    rank += 1

df = pd.DataFrame(song_data, columns = ['서비스','순위','타이틀','가수'])
df
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_3880\1805169112.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
#       서비스   순위                            타이틀            가수
# 0   Genie    1                          Ditto      NewJeans
# 1   Genie    2                            OMG      NewJeans
# 2   Genie    3                       Hype boy      NewJeans
# 3   Genie    4                        사건의 지평선   윤하 (YOUNHA)
# 4   Genie    5  I Don't Think That I Like Her  Charlie Puth
# ..    ...  ...                            ...           ...
# 95  Genie   96                strawberry moon      아이유 (IU)
# 96  Genie   97                         Butter         방탄소년단
# 97  Genie   98                       SNEAKERS     ITZY (있지)
# 98  Genie   99                        나의 목소리로           김호중
# 99  Genie  100                            Bad   Christopher
#
# [100 rows x 4 columns]

# %%
df.to_excel('Genie.xlsx', index=False)

# %%
## 웹툰 타이틀 읽어오기 ####

from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
from pprint import pprint

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://comic.naver.com/webtoon/weekday'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

titles = html.select('a.title')
title = titles[0]
title_tmp = title.text

title_data = []
 

for title in titles:
    title_name = title.text
    title_data.append(title_name)


pprint(title_data)
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_20796\3362664435.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# ['뷰티풀 군바리',
#  '퀘스트지상주의',
#  '신의 탑',
#  '장씨세가 호위무사',
#  '신화급 귀속 아이템을 손에 넣었다',
#  '윈드브레이커',
#  '팔이피플',
#  '소녀의 세계',
#  '버림받은 왕녀의 은밀한 침실',
#  '앵무살수',
#  '별난식당',
#  '똑 닮은 딸',
#  '퍼니게임',
#  '호랑신랑뎐',
#  '잔불의 기사',
#  '히어로메이커',
#  '북부 공작님을 유혹하겠습니다',
#  '물어보는 사이',
#  '꼬리잡기',
#  '신군',
#  '나 없는 단톡방',
#  '순정말고 순종',
#  '결혼생활 그림일기',
#  '루루라라 우리네 인생',
#  '만렙돌파',
#  '이별 후 사내 결혼',
#  '피폐물의 해피엔딩을 위하여',
#  '더블클릭',
#  '또다시, 계약 부부',
#  '파운더',
#  '수영만화일기',
#  '원하나',
#  '토마토가 돼라!',
#  '사이다걸',
#  '꿈의 기업',
#  '강남의 기사',
#  '랭커',
#  '오빠집이 비어서',
#  '사랑의 헌옷수거함',
#  '미니어처 생활백서',
#  '이제야 연애',
#  '악당과 악당이 만나면',
#  '인섹터',
#  '서브 남주가 파업하면 생기는 일',
#  '헬크래프트',
#  '우산 없는 애',
#  '다시쓰는 연애사',
#  '불청객',
#  '하루의 하루',
#  '아슈타르테',
#  '매지컬 급식:암살법사',
#  '메리의 불타는 행복회로',
#  '주작연애',
#  '입술이 예쁜 남자',
#  '라서드',
#  '백호랑',
#  '파견체',
#  '오늘의 비너스',
#  '집사, 주세요!',
#  '영앤리치가 아니야!',
#  '경비실에서 안내방송 드립니다',
#  '도깨비 부른다',
#  '최후의 금빛아이',
#  '굿바이 유교보이',
#  '모스크바의 여명',
#  '버그이터',
#  '너를 돌려차는 방법',
#  '지옥연애환담',
#  '모노마니아',
#  '악녀 18세 공략기',
#  '루크 비셸 따라잡기',
#  '나만의 고막남친',
#  '퇴근 후에 만나요',
#  '중독연구소',
#  '세번째 로망스',
#  '디나운스',
#  '사막에 핀 달',
#  '연애 연기대상',
#  '결혼공략',
#  '오로지 오로라',
#  '행운을 부탁해!',
#  '별을 쫓는 소년들',
#  '슈퍼스타 천대리',
#  '역주행!',
#  '김부장',
#  '대학원 탈출일지',
#  '내가 키운 S급들',
#  '여신강림',
#  '사신소년',
#  '마루는 강쥐',
#  '한림체육관',
#  '멸망 이후의 세계',
#  '사변괴담',
#  '놓지마 정신줄 시즌3',
#  '삼국지톡',
#  '하루만 네가 되고 싶어',
#  '하북팽가 막내아들',
#  '헬58',
#  '궤짝',
#  '집이 없어',
#  '천마는 평범하게 살 수 없다',
#  '악몽의 형상',
#  '호랑이 들어와요',
#  '랜덤채팅의 그녀!',
#  '위아더좀비',
#  '원주민 공포만화',
#  '초인의 게임',
#  '시한부인 줄 알았어요!',
#  '유사연애',
#  '윌유메리미',
#  '나타나주세요!',
#  '우리 집 고양이 보고 갈래?',
#  '시체기사 군터',
#  '돌격! 용마치킨',
#  '저 그런 인재 아닙니다',
#  '덴큐',
#  '짐승의 꽃',
#  '용사가 돌아왔다',
#  '늑대처럼 홀로',
#  '애옹식당',
#  '그냥 선생님',
#  '태시트',
#  '공작저의 붉은 밤',
#  '용왕님의 셰프가 되었습니다',
#  '헥토파스칼',
#  '연우의 순정',
#  '웅크',
#  '왕게임',
#  '빅맨',
#  '에이머',
#  '은주의 방 2~3부',
#  '팀장님은 신혼이 피곤하다',
#  '빌런투킬',
#  '로잘린 보가트',
#  '아이즈',
#  '내남친 킹카만들기',
#  '대공님, 실수였어요!',
#  '사표내고 이계에서 힐링합니다',
#  '열녀박씨 계약결혼뎐',
#  '로맨스가 가능해?',
#  '한입만!',
#  '제로게임',
#  '주인님을 잡아먹는 방법',
#  '짝사랑의 마침표',
#  '풋내기들',
#  '사공은주',
#  '여우자매',
#  '이 결혼, 새로고침',
#  '그 남주와 이별하는 방법',
#  '필리아로제 - 가시왕관의 예언',
#  '햄버거가 제일 좋아',
#  'DARK MOON: 회색 도시',
#  '마침내 사랑이에요 마왕님!',
#  '1331',
#  '원수가 나를 유혹할 때',
#  '급식러너',
#  '달이 사라진 밤',
#  'AI 유하',
#  '찐:종합게임동아리',
#  '마녀이야기',
#  '너의 순정, 나의 순정',
#  '쿠쿠쿠쿠',
#  '교환학생',
#  '전지적 독자 시점',
#  '내 남편과 결혼해줘',
#  '헬퍼 2 : 킬베로스',
#  '백XX',
#  '66666년 만에 환생한 흑마법사',
#  '일렉시드',
#  '무림서부',
#  '튜토리얼 탑의 고인물',
#  '격기3반',
#  '나쁜사람',
#  '황후를 훔친 이는 누구인가',
#  '마른 가지에 바람처럼',
#  '연놈',
#  '내가 죽기로 결심한 것은',
#  '칼에 취한 밤을 걷다',
#  '급식아빠',
#  '헤어지면 죽음',
#  '운명을 보는 회사원',
#  '빌드업',
#  '사상최강',
#  '안녕, 나의 수집',
#  '세상은 돈과 권력',
#  '행성인간2: 행성의',
#  '가짜 동맹',
#  '에브리띵 이즈 파인',
#  '판타지 여동생!',
#  '칼부림',
#  '이십팔세기 광팬',
#  '하렘의 남자들',
#  '언덕 위의 제임스',
#  '누가 나를 죽였을까',
#  '물고기로 살아남기',
#  '마녀와 용의 신혼일기',
#  '수플레 팬 케이크',
#  '히어로 더 맥시멈',
#  '인과관계',
#  '두 마리를 위한 뜰',
#  '케찰코아틀 - 헤수스',
#  '반귀',
#  '수요웹툰의 나강림',
#  '굿헌팅',
#  '괴물공작의 딸',
#  '사내고충처리반',
#  '영웅&마왕&악당',
#  '용한소녀',
#  '겨울 정원의 하와르',
#  '두 번 사는 프로듀서',
#  '메모리얼',
#  '홀리데이',
#  '로어 올림푸스',
#  '주부 육성중',
#  '고교흥신소',
#  '좀간',
#  '그림자의 밤',
#  '밀행',
#  '넷시의 비밀',
#  '옆집남자 친구',
#  '내겐 너무 소란한 결혼',
#  '하얀 사자의 비밀 신부',
#  '선배는 나빠요!',
#  '안미운 우리들',
#  '미시령',
#  '그 남자의 은밀한 하루',
#  '이별학',
#  '재생존경쟁',
#  '반짝반짝 작은 눈',
#  '어느 백작 영애의 이중생활',
#  '멸종위기종인간',
#  '연애고수',
#  '이런 미친 엔딩',
#  '낙원의 이론',
#  '나의 계절',
#  '프로듀스 온리원',
#  '오직, 밝은 미래',
#  '이 짝사랑은 억울하다!',
#  '필생기',
#  '산의 시간',
#  '우리 은하',
#  '앞집나리',
#  '재벌집 막내아들',
#  '연애혁명',
#  '나노마신',
#  '남편을 죽여줘요',
#  '천마육성',
#  '현실퀘스트',
#  '나 혼자 네크로맨서',
#  '무사만리행',
#  '회귀한 천재 헌터의 슬기로운 청소생활',
#  '호랑신랑뎐',
#  '뮤즈 온 유명',
#  '노답소녀',
#  '순정빌런',
#  '별을 삼킨 너에게',
#  '보스였음',
#  '버려진 나의 최애를 위하여',
#  '특수청소',
#  '쿠베라',
#  '국세청 망나니',
#  '규격 외 혈통 천재',
#  '꽃만 키우는데 너무강함',
#  '최강전설 강해효',
#  '이러면 안 돼요, 전하!',
#  '흑막 여주가 날 새엄마로 만들려고 해',
#  '루루라라 우리네 인생',
#  '완벽한 결혼의 정석',
#  '비서 일탈',
#  '게임 최강 트롤러',
#  '네가 죽기를 바랄 때가 있었다',
#  '마왕까지 한 걸음',
#  '만능잡캐',
#  '순수한 동거생활',
#  '누나! 나 무서워',
#  '수영만화일기',
#  '진짜 진짜 이혼해',
#  '해시의 신루',
#  '아인슈페너',
#  '이게 웬 떡',
#  '던전 씹어먹는 아티팩트',
#  '개와 사람의 시간',
#  '선남친 후연애',
#  '킬더킹',
#  '위대한 겸상',
#  '소녀의 디딤돌 : 희망, 함께 날다',
#  '케찰코아틀 - 다빗',
#  '1학년 9반',
#  '코인 리벤지',
#  '두 번째 딸로 태어났습니다',
#  'THE 런웨이',
#  '독거미',
#  '천재의 게임방송',
#  '달의 요람',
#  '마녀의 심판은 꽃이 된다',
#  '베니루 BAENIRU',
#  '오, 친애하는 숙적',
#  '나의 불편한 상사',
#  '환상연가',
#  '황제사냥',
#  '방과후 레시피',
#  '황궁에 핀 꽃은, 미쳤다',
#  '아빠같은 남자',
#  '부캐인생',
#  '엔딩, 바꿔보려합니다',
#  '사기 친 공작님을 유혹해버렸다',
#  '배트맨: 웨인 패밀리 어드벤처',
#  '35cm',
#  '그 황제가 시곗바늘을 되돌린 사연',
#  '트롤트랩',
#  '카루나',
#  '돌아온 여기사',
#  '베어케어',
#  '온실 속 화초',
#  '시에라',
#  '자취방 신선들',
#  '유월의 소한',
#  '로맨틱 태평수산',
#  '보물과 괴물의 도시',
#  '널 사랑하는 죽은 형',
#  '사랑하는 여배우들',
#  '권리행사자',
#  '따개비',
#  '외모지상주의',
#  '대학원 탈출일지',
#  '나 혼자 만렙 뉴비',
#  '어쩌다보니 천생연분',
#  '역대급 영지 설계사',
#  '데드퀸',
#  '1초',
#  '개를 낳았다',
#  '삼국지톡',
#  '상남자',
#  '언니, 이번 생엔 내가 왕비야',
#  '낙향문사전',
#  '천하제일 대사형',
#  '커플브레이커',
#  '연애의 기록',
#  '죽지 않으려면',
#  '서울역 드루이드',
#  '사신',
#  '약탈 신부',
#  'A.I. 닥터',
#  '히어로 킬러',
#  '신컨의 원 코인 클리어',
#  '뫼신 사냥꾼',
#  '더 게이머',
#  '그렇고 그런 바람에',
#  '전남편의 미친개를 길들였다',
#  '브레이커 : 이터널 포스',
#  '바스티안',
#  '언다잉',
#  '세기말 풋사과 보습학원',
#  '플레이어',
#  '그냥 선생님',
#  '폭군님은 착하게 살고 싶어',
#  '선을 넘은 연애',
#  '푸쉬오프',
#  '소름일기',
#  '쌈빡',
#  '여자를 사귀고 싶다',
#  '온리호프',
#  '대위님! 이번 전쟁터는 이곳인가요?',
#  '미친 후작을 길들이고 말았다',
#  '웅크',
#  '연기는 처음인데요?!',
#  '킬 더 드래곤',
#  '후덜덜덜 남극전자',
#  '몽홀',
#  '죽음으로 구원하사',
#  '로또 황녀님',
#  '문제적 왕자님',
#  '스포',
#  '절대복종',
#  '멜빈이 그들에게 남긴 것',
#  '지옥 키우기',
#  '달이 없는 나라',
#  '솔트앤페퍼',
#  '이게 아닌데',
#  '아찔한 전남편',
#  '백년게임',
#  '메소드 연기법',
#  '지니오패스',
#  '악마라고 불러다오',
#  '스토커의 하루',
#  '별빛 커튼콜',
#  '태권보이',
#  '성스러운 그대 이르시길',
#  '푸른 밤, 황홀의 윤무',
#  '인피니티',
#  '드래곤의 심장을 가지고 있습니다',
#  '뜨거운 홍차',
#  '신의 최애캐',
#  '하나는 적고 둘은 너무 많아',
#  '합법해적 파르페',
#  '비밀친구',
#  '우리 무슨 사이야?',
#  '미드우트',
#  '너의 키스씬',
#  '행운을 빌어요, 용사님!',
#  '애증화음',
#  '짝사랑 마들렌',
#  '여우놀이',
#  '천상의 주인',
#  '여름의 너에게',
#  '크림슨 하트',
#  '세라는 망돌',
#  '기억해줘',
#  '스치면 인연 스며들면 사랑',
#  '너에게 입덕중',
#  '쿠쿠쿠쿠',
#  '서울시 천사주의',
#  '99강화나무몽둥이',
#  '호랑이형님',
#  '취사병 전설이 되다',
#  '프리드로우',
#  '놓지마 정신줄 시즌3',
#  '은탄',
#  '스터디그룹',
#  '이종 격투기',
#  '악몽의 형상',
#  '세레나',
#  '나태 공자, 노력 천재 되다',
#  '작전명 순정',
#  '나이트런',
#  '윌유메리미',
#  '청춘 블라썸',
#  '반드시 해피엔딩',
#  '디펜스 게임의 폭군이 되었다',
#  '물위의 우리',
#  '소공녀 민트',
#  '아홉수 우리들',
#  '나를 바꿔줘',
#  '나랑X할래?',
#  '민간인 통제구역 - 일급기밀',
#  '이십팔세기 광팬',
#  '존잘주의',
#  '미나 이퀄',
#  '간첩 18세',
#  '어글리후드',
#  '더 캐슬 - 귀안의 신부',
#  '탑코너',
#  '홍시는 날 좋아해!',
#  '용사참수인',
#  '왕세자 입학도',
#  '이계진입 리로디드',
#  '더 해머',
#  '엑스애쉬',
#  '광해의 연인',
#  '대충 캠퍼스로맨스임',
#  '남편을 만렙으로 키우려 합니다',
#  '폭군 남편과 이혼하겠습니다',
#  '공유몽',
#  '저무는 해, 시린 눈',
#  '전생연분',
#  '내게 필요한 NO맨스',
#  '마법사가 죽음을 맞이하는 방법',
#  '묘령의 황자',
#  '완벽한 부부는 없다',
#  '최강부캐',
#  '최면학교',
#  '소년 검사',
#  '숨겨진 성녀',
#  '키스 식스 센스',
#  '은둔코인',
#  '청춘일지',
#  '중매쟁이 아가 황녀님',
#  '애구애구',
#  '사서고생!',
#  '왕년엔 용사님',
#  '다비, 아찔하게 흐르는',
#  '배달의 신',
#  '용두사망 소설 속의 악녀가 되었다',
#  '아가사',
#  '키스의 여왕',
#  '아침을 지나 밤으로',
#  '7FATES: CHAKHO',
#  '시선 끝 브로콜리',
#  '아이돌만 하고 싶었는데',
#  '궤도의 아이들',
#  '밤을 깨우는 마법',
#  '겨울특강',
#  '이건 그냥 연애 이야기',
#  '메트로헌터',
#  '보고 있지?',
#  '실버 쥬얼',
#  '싸움독학',
#  '약한영웅',
#  '입학용병',
#  '사형소년',
#  '일타강사 백사부',
#  '가비지타임',
#  '시월드가 내게 집착한다',
#  '고양이 타타',
#  '나 혼자 특성빨로 무한 성장',
#  '투신전생기',
#  '수희0(tngmlek0)',
#  '천화서고 대공자',
#  '자매전쟁',
#  '안녕, 나의 수집',
#  '노빠꾸 최하영',
#  '판사 이한영',
#  '무진',
#  '소녀재판',
#  '분신으로 자동사냥',
#  '아카데미에 위장취업당했다',
#  '내일',
#  '살아남은 로맨스',
#  '마법스크롤 상인 지오',
#  '폰투스 : 극야2',
#  '밤마다 남편이 바뀐다',
#  '무서운게 딱좋아!',
#  '합격시켜주세용',
#  '아포크리파',
#  '신혼부부 생활 백서',
#  '장풍전',
#  '어느날 갑자기 서울은',
#  '경자 전성시대',
#  '위닝샷!',
#  '고백 취소도 되나?',
#  '칼끝에 입술',
#  '약빨이 신선함',
#  '후궁 스캔들',
#  '이세계 용사가 지구를 구하는 이유',
#  '사랑은 없는 것처럼',
#  '장미같은 소리',
#  '천치전능',
#  '첫날밤만 세 번째',
#  '헬스던전',
#  '전설의 화석',
#  '청춘계시록',
#  '여우애담',
#  '돌&아이',
#  '몸이 바뀌는 사정',
#  '평행도시',
#  '노량진 공격대',
#  '데빌샷',
#  '결혼까지 망상했어!',
#  '키미앤조이',
#  '사람은 고쳐 쓰는 게 아니야!',
#  '위험한 남편을 길들이는 법',
#  '나의 작은 서점',
#  '홍 의관의 은밀한 비밀',
#  '백설을 위하여',
#  '마왕의 고백',
#  '108명의 그녀들',
#  '생존고백',
#  '네 것이었던 것',
#  '내곁엔 없을까',
#  '패션쇼',
#  '잿더미 황후',
#  '인생영화',
#  '킬링킬러',
#  '여신님의 호랑이 공략법',
#  '손 안의 안단테',
#  '마도',
#  '6월의 라벤더',
#  '완벽한 파트너',
#  'DARK MOON: 달의 제단',
#  '보스의 노골적 취향',
#  '마섹남 - 마술하는 섹시한 남자',
#  '블러드 리벤저',
#  '철수와 영희 이야기',
#  '하렘에서 살아남기',
#  '신이 담긴 아이',
#  '샤인 스타',
#  '조선여우스캔들',
#  '밀실 마피아 게임',
#  '아마도, 굿모닝',
#  '천년간 노려왔습니다',
#  '그림자 잡기',
#  '어떤소란']

# %%
from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
from pprint import pprint

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://comic.naver.com/webtoon/weekday'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

# titles = html.select('a.title') select 문법

titles = html.findAll('a', {'class' : 'title'})
titles = [title.text for title in titles ]
pprint(titles)
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_20796\3242541004.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# ['뷰티풀 군바리',
#  '퀘스트지상주의',
#  '신의 탑',
#  '장씨세가 호위무사',
#  '신화급 귀속 아이템을 손에 넣었다',
#  '윈드브레이커',
#  '팔이피플',
#  '소녀의 세계',
#  '버림받은 왕녀의 은밀한 침실',
#  '앵무살수',
#  '별난식당',
#  '똑 닮은 딸',
#  '퍼니게임',
#  '호랑신랑뎐',
#  '잔불의 기사',
#  '히어로메이커',
#  '북부 공작님을 유혹하겠습니다',
#  '물어보는 사이',
#  '꼬리잡기',
#  '신군',
#  '나 없는 단톡방',
#  '순정말고 순종',
#  '결혼생활 그림일기',
#  '루루라라 우리네 인생',
#  '만렙돌파',
#  '이별 후 사내 결혼',
#  '피폐물의 해피엔딩을 위하여',
#  '더블클릭',
#  '또다시, 계약 부부',
#  '파운더',
#  '수영만화일기',
#  '원하나',
#  '토마토가 돼라!',
#  '사이다걸',
#  '꿈의 기업',
#  '강남의 기사',
#  '랭커',
#  '오빠집이 비어서',
#  '사랑의 헌옷수거함',
#  '미니어처 생활백서',
#  '이제야 연애',
#  '악당과 악당이 만나면',
#  '인섹터',
#  '서브 남주가 파업하면 생기는 일',
#  '헬크래프트',
#  '우산 없는 애',
#  '다시쓰는 연애사',
#  '불청객',
#  '하루의 하루',
#  '아슈타르테',
#  '매지컬 급식:암살법사',
#  '메리의 불타는 행복회로',
#  '주작연애',
#  '입술이 예쁜 남자',
#  '라서드',
#  '백호랑',
#  '파견체',
#  '오늘의 비너스',
#  '집사, 주세요!',
#  '영앤리치가 아니야!',
#  '경비실에서 안내방송 드립니다',
#  '도깨비 부른다',
#  '최후의 금빛아이',
#  '굿바이 유교보이',
#  '모스크바의 여명',
#  '버그이터',
#  '너를 돌려차는 방법',
#  '지옥연애환담',
#  '모노마니아',
#  '악녀 18세 공략기',
#  '루크 비셸 따라잡기',
#  '나만의 고막남친',
#  '퇴근 후에 만나요',
#  '중독연구소',
#  '세번째 로망스',
#  '디나운스',
#  '사막에 핀 달',
#  '연애 연기대상',
#  '결혼공략',
#  '오로지 오로라',
#  '행운을 부탁해!',
#  '별을 쫓는 소년들',
#  '슈퍼스타 천대리',
#  '역주행!',
#  '김부장',
#  '대학원 탈출일지',
#  '내가 키운 S급들',
#  '여신강림',
#  '사신소년',
#  '마루는 강쥐',
#  '한림체육관',
#  '멸망 이후의 세계',
#  '사변괴담',
#  '놓지마 정신줄 시즌3',
#  '삼국지톡',
#  '하루만 네가 되고 싶어',
#  '하북팽가 막내아들',
#  '헬58',
#  '궤짝',
#  '집이 없어',
#  '천마는 평범하게 살 수 없다',
#  '악몽의 형상',
#  '호랑이 들어와요',
#  '랜덤채팅의 그녀!',
#  '위아더좀비',
#  '원주민 공포만화',
#  '초인의 게임',
#  '시한부인 줄 알았어요!',
#  '유사연애',
#  '윌유메리미',
#  '나타나주세요!',
#  '우리 집 고양이 보고 갈래?',
#  '시체기사 군터',
#  '돌격! 용마치킨',
#  '저 그런 인재 아닙니다',
#  '덴큐',
#  '짐승의 꽃',
#  '용사가 돌아왔다',
#  '늑대처럼 홀로',
#  '애옹식당',
#  '그냥 선생님',
#  '태시트',
#  '공작저의 붉은 밤',
#  '용왕님의 셰프가 되었습니다',
#  '헥토파스칼',
#  '연우의 순정',
#  '웅크',
#  '왕게임',
#  '빅맨',
#  '에이머',
#  '은주의 방 2~3부',
#  '팀장님은 신혼이 피곤하다',
#  '빌런투킬',
#  '로잘린 보가트',
#  '아이즈',
#  '내남친 킹카만들기',
#  '대공님, 실수였어요!',
#  '사표내고 이계에서 힐링합니다',
#  '열녀박씨 계약결혼뎐',
#  '로맨스가 가능해?',
#  '한입만!',
#  '제로게임',
#  '주인님을 잡아먹는 방법',
#  '짝사랑의 마침표',
#  '풋내기들',
#  '사공은주',
#  '여우자매',
#  '이 결혼, 새로고침',
#  '그 남주와 이별하는 방법',
#  '필리아로제 - 가시왕관의 예언',
#  '햄버거가 제일 좋아',
#  'DARK MOON: 회색 도시',
#  '마침내 사랑이에요 마왕님!',
#  '1331',
#  '원수가 나를 유혹할 때',
#  '급식러너',
#  '달이 사라진 밤',
#  'AI 유하',
#  '찐:종합게임동아리',
#  '마녀이야기',
#  '너의 순정, 나의 순정',
#  '쿠쿠쿠쿠',
#  '교환학생',
#  '전지적 독자 시점',
#  '내 남편과 결혼해줘',
#  '헬퍼 2 : 킬베로스',
#  '백XX',
#  '66666년 만에 환생한 흑마법사',
#  '일렉시드',
#  '무림서부',
#  '튜토리얼 탑의 고인물',
#  '격기3반',
#  '나쁜사람',
#  '황후를 훔친 이는 누구인가',
#  '마른 가지에 바람처럼',
#  '연놈',
#  '내가 죽기로 결심한 것은',
#  '칼에 취한 밤을 걷다',
#  '급식아빠',
#  '헤어지면 죽음',
#  '운명을 보는 회사원',
#  '빌드업',
#  '사상최강',
#  '안녕, 나의 수집',
#  '세상은 돈과 권력',
#  '행성인간2: 행성의',
#  '가짜 동맹',
#  '에브리띵 이즈 파인',
#  '판타지 여동생!',
#  '칼부림',
#  '이십팔세기 광팬',
#  '하렘의 남자들',
#  '언덕 위의 제임스',
#  '누가 나를 죽였을까',
#  '물고기로 살아남기',
#  '마녀와 용의 신혼일기',
#  '수플레 팬 케이크',
#  '히어로 더 맥시멈',
#  '인과관계',
#  '두 마리를 위한 뜰',
#  '케찰코아틀 - 헤수스',
#  '반귀',
#  '수요웹툰의 나강림',
#  '굿헌팅',
#  '괴물공작의 딸',
#  '사내고충처리반',
#  '영웅&마왕&악당',
#  '용한소녀',
#  '겨울 정원의 하와르',
#  '두 번 사는 프로듀서',
#  '메모리얼',
#  '홀리데이',
#  '로어 올림푸스',
#  '주부 육성중',
#  '고교흥신소',
#  '좀간',
#  '그림자의 밤',
#  '밀행',
#  '넷시의 비밀',
#  '옆집남자 친구',
#  '내겐 너무 소란한 결혼',
#  '하얀 사자의 비밀 신부',
#  '선배는 나빠요!',
#  '안미운 우리들',
#  '미시령',
#  '그 남자의 은밀한 하루',
#  '이별학',
#  '재생존경쟁',
#  '반짝반짝 작은 눈',
#  '어느 백작 영애의 이중생활',
#  '멸종위기종인간',
#  '연애고수',
#  '이런 미친 엔딩',
#  '낙원의 이론',
#  '나의 계절',
#  '프로듀스 온리원',
#  '오직, 밝은 미래',
#  '이 짝사랑은 억울하다!',
#  '필생기',
#  '산의 시간',
#  '우리 은하',
#  '앞집나리',
#  '재벌집 막내아들',
#  '연애혁명',
#  '나노마신',
#  '남편을 죽여줘요',
#  '천마육성',
#  '현실퀘스트',
#  '나 혼자 네크로맨서',
#  '무사만리행',
#  '회귀한 천재 헌터의 슬기로운 청소생활',
#  '호랑신랑뎐',
#  '뮤즈 온 유명',
#  '노답소녀',
#  '순정빌런',
#  '별을 삼킨 너에게',
#  '보스였음',
#  '버려진 나의 최애를 위하여',
#  '특수청소',
#  '쿠베라',
#  '국세청 망나니',
#  '규격 외 혈통 천재',
#  '꽃만 키우는데 너무강함',
#  '최강전설 강해효',
#  '이러면 안 돼요, 전하!',
#  '흑막 여주가 날 새엄마로 만들려고 해',
#  '루루라라 우리네 인생',
#  '완벽한 결혼의 정석',
#  '비서 일탈',
#  '게임 최강 트롤러',
#  '네가 죽기를 바랄 때가 있었다',
#  '마왕까지 한 걸음',
#  '만능잡캐',
#  '순수한 동거생활',
#  '누나! 나 무서워',
#  '수영만화일기',
#  '진짜 진짜 이혼해',
#  '해시의 신루',
#  '아인슈페너',
#  '이게 웬 떡',
#  '던전 씹어먹는 아티팩트',
#  '개와 사람의 시간',
#  '선남친 후연애',
#  '킬더킹',
#  '위대한 겸상',
#  '소녀의 디딤돌 : 희망, 함께 날다',
#  '케찰코아틀 - 다빗',
#  '1학년 9반',
#  '코인 리벤지',
#  '두 번째 딸로 태어났습니다',
#  'THE 런웨이',
#  '독거미',
#  '천재의 게임방송',
#  '달의 요람',
#  '마녀의 심판은 꽃이 된다',
#  '베니루 BAENIRU',
#  '오, 친애하는 숙적',
#  '나의 불편한 상사',
#  '환상연가',
#  '황제사냥',
#  '방과후 레시피',
#  '황궁에 핀 꽃은, 미쳤다',
#  '아빠같은 남자',
#  '부캐인생',
#  '엔딩, 바꿔보려합니다',
#  '사기 친 공작님을 유혹해버렸다',
#  '배트맨: 웨인 패밀리 어드벤처',
#  '35cm',
#  '그 황제가 시곗바늘을 되돌린 사연',
#  '트롤트랩',
#  '카루나',
#  '돌아온 여기사',
#  '베어케어',
#  '온실 속 화초',
#  '시에라',
#  '자취방 신선들',
#  '유월의 소한',
#  '로맨틱 태평수산',
#  '보물과 괴물의 도시',
#  '널 사랑하는 죽은 형',
#  '사랑하는 여배우들',
#  '권리행사자',
#  '따개비',
#  '외모지상주의',
#  '대학원 탈출일지',
#  '나 혼자 만렙 뉴비',
#  '어쩌다보니 천생연분',
#  '역대급 영지 설계사',
#  '데드퀸',
#  '1초',
#  '개를 낳았다',
#  '삼국지톡',
#  '상남자',
#  '언니, 이번 생엔 내가 왕비야',
#  '낙향문사전',
#  '천하제일 대사형',
#  '커플브레이커',
#  '연애의 기록',
#  '죽지 않으려면',
#  '서울역 드루이드',
#  '사신',
#  '약탈 신부',
#  'A.I. 닥터',
#  '히어로 킬러',
#  '신컨의 원 코인 클리어',
#  '뫼신 사냥꾼',
#  '더 게이머',
#  '그렇고 그런 바람에',
#  '전남편의 미친개를 길들였다',
#  '브레이커 : 이터널 포스',
#  '바스티안',
#  '언다잉',
#  '세기말 풋사과 보습학원',
#  '플레이어',
#  '그냥 선생님',
#  '폭군님은 착하게 살고 싶어',
#  '선을 넘은 연애',
#  '푸쉬오프',
#  '소름일기',
#  '쌈빡',
#  '여자를 사귀고 싶다',
#  '온리호프',
#  '대위님! 이번 전쟁터는 이곳인가요?',
#  '미친 후작을 길들이고 말았다',
#  '웅크',
#  '연기는 처음인데요?!',
#  '킬 더 드래곤',
#  '후덜덜덜 남극전자',
#  '몽홀',
#  '죽음으로 구원하사',
#  '로또 황녀님',
#  '문제적 왕자님',
#  '스포',
#  '절대복종',
#  '멜빈이 그들에게 남긴 것',
#  '지옥 키우기',
#  '달이 없는 나라',
#  '솔트앤페퍼',
#  '이게 아닌데',
#  '아찔한 전남편',
#  '백년게임',
#  '메소드 연기법',
#  '지니오패스',
#  '악마라고 불러다오',
#  '스토커의 하루',
#  '별빛 커튼콜',
#  '태권보이',
#  '성스러운 그대 이르시길',
#  '푸른 밤, 황홀의 윤무',
#  '인피니티',
#  '드래곤의 심장을 가지고 있습니다',
#  '뜨거운 홍차',
#  '신의 최애캐',
#  '하나는 적고 둘은 너무 많아',
#  '합법해적 파르페',
#  '비밀친구',
#  '우리 무슨 사이야?',
#  '미드우트',
#  '너의 키스씬',
#  '행운을 빌어요, 용사님!',
#  '애증화음',
#  '짝사랑 마들렌',
#  '여우놀이',
#  '천상의 주인',
#  '여름의 너에게',
#  '크림슨 하트',
#  '세라는 망돌',
#  '기억해줘',
#  '스치면 인연 스며들면 사랑',
#  '너에게 입덕중',
#  '쿠쿠쿠쿠',
#  '서울시 천사주의',
#  '99강화나무몽둥이',
#  '호랑이형님',
#  '취사병 전설이 되다',
#  '프리드로우',
#  '놓지마 정신줄 시즌3',
#  '은탄',
#  '스터디그룹',
#  '이종 격투기',
#  '악몽의 형상',
#  '세레나',
#  '나태 공자, 노력 천재 되다',
#  '작전명 순정',
#  '나이트런',
#  '윌유메리미',
#  '청춘 블라썸',
#  '반드시 해피엔딩',
#  '디펜스 게임의 폭군이 되었다',
#  '물위의 우리',
#  '소공녀 민트',
#  '아홉수 우리들',
#  '나를 바꿔줘',
#  '나랑X할래?',
#  '민간인 통제구역 - 일급기밀',
#  '이십팔세기 광팬',
#  '존잘주의',
#  '미나 이퀄',
#  '간첩 18세',
#  '어글리후드',
#  '더 캐슬 - 귀안의 신부',
#  '탑코너',
#  '홍시는 날 좋아해!',
#  '용사참수인',
#  '왕세자 입학도',
#  '이계진입 리로디드',
#  '더 해머',
#  '엑스애쉬',
#  '광해의 연인',
#  '대충 캠퍼스로맨스임',
#  '남편을 만렙으로 키우려 합니다',
#  '폭군 남편과 이혼하겠습니다',
#  '공유몽',
#  '저무는 해, 시린 눈',
#  '전생연분',
#  '내게 필요한 NO맨스',
#  '마법사가 죽음을 맞이하는 방법',
#  '묘령의 황자',
#  '완벽한 부부는 없다',
#  '최강부캐',
#  '최면학교',
#  '소년 검사',
#  '숨겨진 성녀',
#  '키스 식스 센스',
#  '은둔코인',
#  '청춘일지',
#  '중매쟁이 아가 황녀님',
#  '애구애구',
#  '사서고생!',
#  '왕년엔 용사님',
#  '다비, 아찔하게 흐르는',
#  '배달의 신',
#  '용두사망 소설 속의 악녀가 되었다',
#  '아가사',
#  '키스의 여왕',
#  '아침을 지나 밤으로',
#  '7FATES: CHAKHO',
#  '시선 끝 브로콜리',
#  '아이돌만 하고 싶었는데',
#  '궤도의 아이들',
#  '밤을 깨우는 마법',
#  '겨울특강',
#  '이건 그냥 연애 이야기',
#  '메트로헌터',
#  '보고 있지?',
#  '실버 쥬얼',
#  '싸움독학',
#  '약한영웅',
#  '입학용병',
#  '사형소년',
#  '일타강사 백사부',
#  '가비지타임',
#  '시월드가 내게 집착한다',
#  '고양이 타타',
#  '나 혼자 특성빨로 무한 성장',
#  '투신전생기',
#  '수희0(tngmlek0)',
#  '천화서고 대공자',
#  '자매전쟁',
#  '안녕, 나의 수집',
#  '노빠꾸 최하영',
#  '판사 이한영',
#  '무진',
#  '소녀재판',
#  '분신으로 자동사냥',
#  '아카데미에 위장취업당했다',
#  '내일',
#  '살아남은 로맨스',
#  '마법스크롤 상인 지오',
#  '폰투스 : 극야2',
#  '밤마다 남편이 바뀐다',
#  '무서운게 딱좋아!',
#  '합격시켜주세용',
#  '아포크리파',
#  '신혼부부 생활 백서',
#  '장풍전',
#  '어느날 갑자기 서울은',
#  '경자 전성시대',
#  '위닝샷!',
#  '고백 취소도 되나?',
#  '칼끝에 입술',
#  '약빨이 신선함',
#  '후궁 스캔들',
#  '이세계 용사가 지구를 구하는 이유',
#  '사랑은 없는 것처럼',
#  '장미같은 소리',
#  '천치전능',
#  '첫날밤만 세 번째',
#  '헬스던전',
#  '전설의 화석',
#  '청춘계시록',
#  '여우애담',
#  '돌&아이',
#  '몸이 바뀌는 사정',
#  '평행도시',
#  '노량진 공격대',
#  '데빌샷',
#  '결혼까지 망상했어!',
#  '키미앤조이',
#  '사람은 고쳐 쓰는 게 아니야!',
#  '위험한 남편을 길들이는 법',
#  '나의 작은 서점',
#  '홍 의관의 은밀한 비밀',
#  '백설을 위하여',
#  '마왕의 고백',
#  '108명의 그녀들',
#  '생존고백',
#  '네 것이었던 것',
#  '내곁엔 없을까',
#  '패션쇼',
#  '잿더미 황후',
#  '인생영화',
#  '킬링킬러',
#  '여신님의 호랑이 공략법',
#  '손 안의 안단테',
#  '마도',
#  '6월의 라벤더',
#  '완벽한 파트너',
#  'DARK MOON: 달의 제단',
#  '보스의 노골적 취향',
#  '마섹남 - 마술하는 섹시한 남자',
#  '블러드 리벤저',
#  '철수와 영희 이야기',
#  '하렘에서 살아남기',
#  '신이 담긴 아이',
#  '샤인 스타',
#  '조선여우스캔들',
#  '밀실 마피아 게임',
#  '아마도, 굿모닝',
#  '천년간 노려왔습니다',
#  '그림자 잡기',
#  '어떤소란']

# %%
## 네이버 현재 날씨 읽어오기 ( 내가 한 것)

from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://weather.naver.com/'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)

weather = html.select('.summary_img > strong.current ')[0].text.strip()
weather
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_3880\3354966227.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# '현재 온도6.6°'

# %%
## 네이버 현재 날씨 읽어오기 (강사님이랑 한 것)

import requests
txt = requests.get('https://weather.naver.com/')
html = bs(txt.text)

html.select('strong.current')[0].text.strip()
temp = html.select('strong.current')[0].text.strip()
temp[5:]
# Out:
# '6.6°'

# %%
from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
from pprint import pprint 

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://www.bithumb.com/react/'
driver.get(url)

txt = driver.page_source      # 이때 읽어온 데이터는 그냥 글자
html = bs(txt)


coins = html.findAll('strong', {'class':'MarketRow_sort-real__5zeND'})
#coin = coins[0]
#coins = [coin.text for coin in coins]
#coins = [coin.text for coin in coins]
pprint(coins)
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_20796\4187724836.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# []

# %%
########### 네이버 썸네일 모두 자동으로 다운 받기
from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
import requests

url = 'https://comic.naver.com/webtoon/weekday'
txt = requests.get(url)
html = bs(txt.text)

tlist = html.findAll('div', {'class' : 'col_inner'})

# %%
# 사진 다운로드 
# from urllib.request import urlretrieve 파일 다운 모듈
import re

li_list = []

for data in tlist:
    # 제목과 썸네일 영역 추출
    li_list.extend(data.findAll('li')) # 해당 부분을 찾아 병합
    
# pprint(li_list)    

# 썸네일과 제목 추출
for li in li_list:
    img = li.find('img')
    title = img['title']
    img_src = img['src']
    # print(title, img_src)
    #특수 문자 제거
    title = re.sub('[^0-9a-zA-Zㄱ-힗]', '', title)

#    urlretrieve(img_src, title+'.jpg')

# %%
# 파이썬으로 브라우저 크롬 컨트롤

from selenium import webdriver        # 웹 브라우저 컨트롤 (크롬)
from bs4 import BeautifulSoup as bs   # 데이터 분석을 용이하게 정제
import pandas as pd                   # 데이터 분석 관련 모듈
import time

driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
url = 'https://www.youtube.com'
driver.get(url)

time.sleep(3) # 읽어 올 시간을 주기위해 타임 설정

# 검색어 창을 찾기
search = driver.find_element_by_xpath('//*[@id="search]')

#찾은 검색어 창에 검색어 입력
search.send_keys('chat gpt')
# Out:
# C:\Users\두현\AppData\Local\Temp\ipykernel_17108\1521030072.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')  # 버전 주의
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 15
#      12 time.sleep(3) # 읽어 올 시간을 주기위해 타임 설정
#      14 # 검색어 창을 찾기
# ---> 15 search = driver.find_element_by_xpath('//*[@id="search]')
#      17 #찾은 검색어 창에 검색어 입력
#      18 search.send_keys('chat gpt')
#
# AttributeError: 'WebDriver' object has no attribute 'find_element_by_xpath'
